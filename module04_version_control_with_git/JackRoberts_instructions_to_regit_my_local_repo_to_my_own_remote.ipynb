# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# https://app.slack.com/client/T02TJEC0W7M/C02V4K2K5HC

# %%
# !jupyter --paths
# Out:
# config:
#     C:\Users\dmassegur\.jupyter
#     C:\Users\dmassegur\AppData\Roaming\Python\etc\jupyter
#     C:\Users\dmassegur\Anaconda3\envs\rse_course_2022\etc\jupyter
#     C:\ProgramData\jupyter
# data:
#     C:\Users\dmassegur\AppData\Roaming\jupyter
#     C:\Users\dmassegur\AppData\Roaming\Python\share\jupyter
#     C:\Users\dmassegur\Anaconda3\envs\rse_course_2022\share\jupyter
#     C:\ProgramData\jupyter
# runtime:
#     C:\Users\dmassegur\AppData\Roaming\jupyter\runtime
